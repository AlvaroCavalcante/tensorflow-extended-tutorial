# %% [markdown]
# # Exemplo aplicação TensorFlow Data Validation
# Esse notebook possui um exemplo prático da aplicação do TF Data Validation e o TensorFlow Transform. Os links das documentações oficiais estão abaixo:
#
# Tutorial de *getting started* do TFDV:
# - https://www.tensorflow.org/tfx/data_validation/get_started
#
# Tipos de anomalias que podemos detectar com o TFDV:
# - https://github.com/tensorflow/metadata/blob/master/tensorflow_metadata/proto/v0/anomalies.proto

# %% [markdown]
# ## Instalação e importação das bibliotecas

# %%
import tensorflow as tf

print('Installing TensorFlow Data Validation')
# !pip install -q tensorflow_data_validation[visualization]
# Out:
# Installing TensorFlow Data Validation
#      |████████████████████████████████| 2.4MB 2.8MB/s
#      |████████████████████████████████| 112kB 12.9MB/s
#      |████████████████████████████████| 3.5MB 17.3MB/s
#      |████████████████████████████████| 2.0MB 42.7MB/s
#      |████████████████████████████████| 63.2MB 53kB/s
#      |████████████████████████████████| 296kB 44.8MB/s
#      |████████████████████████████████| 10.4MB 45.9MB/s
#      |████████████████████████████████| 327kB 51.8MB/s
#      |████████████████████████████████| 788kB 39.0MB/s
#      |████████████████████████████████| 1.2MB 47.9MB/s
#      |████████████████████████████████| 51kB 6.2MB/s
#      |████████████████████████████████| 225kB 47.8MB/s
#      |████████████████████████████████| 61kB 7.7MB/s
#      |████████████████████████████████| 81kB 8.1MB/s
#      |████████████████████████████████| 184kB 41.5MB/s
#      |████████████████████████████████| 174kB 45.7MB/s
#      |████████████████████████████████| 92kB 10.1MB/s
#      |████████████████████████████████| 440kB 46.4MB/s
#      |████████████████████████████████| 153kB 52.5MB/s
#      |████████████████████████████████| 92kB 10.9MB/s
#      |████████████████████████████████| 122kB 51.3MB/s
#      |████████████████████████████████| 215kB 41.6MB/s
#      |████████████████████████████████| 235kB 52.0MB/s
#      |████████████████████████████████| 358kB 49.8MB/s
#      |████████████████████████████████| 112kB 47.7MB/s
#   Building wheel for absl-py (setup.py) ... done
#   Building wheel for avro-python3 (setup.py) ... done
#   Building wheel for hdfs (setup.py) ... done
#   Building wheel for httplib2 (setup.py) ... done
#   Building wheel for oauth2client (setup.py) ... done
#   Building wheel for google-apitools (setup.py) ... done
#   Building wheel for grpc-google-iam-v1 (setup.py) ... done
# ERROR: pydrive 1.3.1 has requirement oauth2client>=4.0.0, but you'll have oauth2client 3.0.0 which is incompatible.
# ERROR: jupyter-console 5.2.0 has requirement prompt-toolkit<2.0.0,>=1.0.0, but you'll have prompt-toolkit 3.0.5 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement ipython~=5.5.0, but you'll have ipython 7.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement pandas~=1.0.0; python_version >= "3.0", but you'll have pandas 0.25.3 which is incompatible.
# ERROR: google-api-python-client 1.7.12 has requirement httplib2<1dev,>=0.17.0, but you'll have httplib2 0.12.0 which is incompatible.
# ERROR: chainer 6.5.0 has requirement typing-extensions<=3.6.6, but you'll have typing-extensions 3.7.4.2 which is incompatible.

# %% [markdown]
# **IMPORTANTE**
#
#
# Após a instalação da biblioteca acima, é necessário reiniciar o Runtime do notebook, para isso vá em: **Runtime > Restart runtime**.
#
# Feito isso, vamos prosseguir com o import das demais bibliotecas que serão usadas:

# %%
import tensorflow_data_validation as tfdv
import pandas as pd
# Out:
# Error importing tfx_bsl_extension.arrow.array_util. Some tfx_bsl functionalities are not availableError importing tfx_bsl_extension.arrow.table_util. Some tfx_bsl functionalities are not available: libarrow.so.16: cannot open shared object file: No such file or directoryError importing tfx_bsl_extension.coders. Some tfx_bsl functionalities are not available

# %% [markdown]
# ## Leitura do dataframe
#
# Vamos ler o arquivo CSV para transformá - lo em um dataframe.

# %%
dataframe = pd.read_csv('iris.csv')
dataframe = dataframe.sample(frac=1)
dataframe.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-254dd2dd4072> in <module>()
# ----> 1 dataframe = pd.read_csv('iris.csv')
#       2 dataframe = dataframe.sample(frac=1)
#       3 dataframe.head()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Gerando as estatísticas manualmente
#
# Uma opção do próprio pandas que nos permite observar algumas estatísticas do dataframe:

# %%
dataframe.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ce19bf65a32d> in <module>()
# ----> 1 dataframe.describe()
#
# NameError: name 'dataframe' is not defined

# %%
dataframe_treinamento = dataframe[:100]
dataframe_teste = dataframe[100:]

# %% [markdown]
# ## Geração de estatísticas com TFDV
# - Utiliza o apache beam para paralelismo a fim de melhorar a performance em grandes datasets.
# - Utiliza o Facets https://pair-code.github.io/facets/

# %%
estatisticas_treinamento = tfdv.generate_statistics_from_dataframe(dataframe = dataframe_treinamento)
estatisticas_treinamento
# Out:
# datasets {
#   num_examples: 100
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 100
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 100
#       }
#       mean: 5.813000000000001
#       std_dev: 0.8514287991370687
#       min: 4.3
#       median: 5.800000190734863
#       max: 7.9
#       histograms {
#         buckets {
#           low_value: 4.300000190734863
#           high_value: 4.66000018119812
#           sample_count: 4.960000333786329
#         }
#         buckets {
#           low_value: 4.66000018119812
#           high_value: 5.020000171661377
#           sample_count: 19.959999856948716
#         }
#         buckets {
#           low_value: 5.020000171661377
#           high_value: 5.380000162124634
#           sample_count: 10.059999856948716
#         }
#         buckets {
#           low_value: 5.380000162124634
#           high_value: 5.740000152587891
#           sample_count: 14.960000143050374
#         }
#         buckets {
#           low_value: 5.740000152587891
#           high_value: 6.1000001430511475
#           sample_count: 13.960000047684671
#         }
#         buckets {
#           low_value: 6.1000001430511475
#           high_value: 6.460000133514404
#           sample_count: 14.059999856948716
#         }
#         buckets {
#           low_value: 6.460000133514404
#           high_value: 6.82000012397766
#           sample_count: 9.959999856948716
#         }
#         buckets {
#           low_value: 6.82000012397766
#           high_value: 7.180000114440918
#           sample_count: 4.06000033378633
#         }
#         buckets {
#           low_value: 7.180000114440918
#           high_value: 7.540000104904175
#           sample_count: 2.9899997854230747
#         }
#         buckets {
#           low_value: 7.540000104904175
#           high_value: 7.900000095367432
#           sample_count: 5.029999928474359
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 4.300000190734863
#           high_value: 4.800000190734863
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 4.800000190734863
#           high_value: 5.0
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 5.0
#           high_value: 5.099999904632568
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 5.099999904632568
#           high_value: 5.5
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 5.5
#           high_value: 5.800000190734863
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 5.800000190734863
#           high_value: 6.0
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 6.0
#           high_value: 6.300000190734863
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 6.300000190734863
#           high_value: 6.5
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 6.5
#           high_value: 7.0
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 7.0
#           high_value: 7.900000095367432
#           sample_count: 10.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "sepal-length"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 100
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 100
#       }
#       mean: 3.089
#       std_dev: 0.4538490938627079
#       min: 2.2
#       median: 3.0
#       max: 4.4
#       histograms {
#         buckets {
#           low_value: 2.200000047683716
#           high_value: 2.4200000524520875
#           sample_count: 5.9199999761581195
#         }
#         buckets {
#           low_value: 2.4200000524520875
#           high_value: 2.640000057220459
#           sample_count: 11.020000119209177
#         }
#         buckets {
#           low_value: 2.640000057220459
#           high_value: 2.8600000619888304
#           sample_count: 14.019999928474528
#         }
#         buckets {
#           low_value: 2.8600000619888304
#           high_value: 3.080000066757202
#           sample_count: 22.020000119209456
#         }
#         buckets {
#           low_value: 3.080000066757202
#           high_value: 3.3000000715255737
#           sample_count: 19.919999976157833
#         }
#         buckets {
#           low_value: 3.3000000715255737
#           high_value: 3.5200000762939454
#           sample_count: 12.019999976158404
#         }
#         buckets {
#           low_value: 3.5200000762939454
#           high_value: 3.740000081062317
#           sample_count: 6.01999997615812
#         }
#         buckets {
#           low_value: 3.740000081062317
#           high_value: 3.9600000858306883
#           sample_count: 5.01999997615812
#         }
#         buckets {
#           low_value: 3.9600000858306883
#           high_value: 4.18000009059906
#           sample_count: 2.0200002145769265
#         }
#         buckets {
#           low_value: 4.18000009059906
#           high_value: 4.400000095367432
#           sample_count: 2.0199997377393126
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 2.200000047683716
#           high_value: 2.5
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 2.5
#           high_value: 2.700000047683716
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 2.700000047683716
#           high_value: 2.799999952316284
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 2.799999952316284
#           high_value: 3.0
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.0
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.200000047683716
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 3.200000047683716
#           high_value: 3.299999952316284
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 3.299999952316284
#           high_value: 3.5
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 3.5
#           high_value: 3.700000047683716
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 3.700000047683716
#           high_value: 4.400000095367432
#           sample_count: 10.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "sepal-width"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 100
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 100
#       }
#       mean: 3.6310000000000002
#       std_dev: 1.8350310624073913
#       min: 1.0
#       median: 4.300000190734863
#       max: 6.9
#       histograms {
#         buckets {
#           low_value: 1.0
#           high_value: 1.5900000095367433
#           sample_count: 28.989999988079077
#         }
#         buckets {
#           low_value: 1.5900000095367433
#           high_value: 2.1800000190734865
#           sample_count: 8.935454560725155
#         }
#         buckets {
#           low_value: 2.1800000190734865
#           high_value: 2.7700000286102293
#           sample_count: 0.05363636334080339
#         }
#         buckets {
#           low_value: 2.7700000286102293
#           high_value: 3.3600000381469726
#           sample_count: 2.950909123617747
#         }
#         buckets {
#           low_value: 3.3600000381469726
#           high_value: 3.950000047683716
#           sample_count: 2.0199999642372215
#         }
#         buckets {
#           low_value: 3.950000047683716
#           high_value: 4.540000057220459
#           sample_count: 16.99000009536752
#         }
#         buckets {
#           low_value: 4.540000057220459
#           high_value: 5.130000066757202
#           sample_count: 17.99000009536752
#         }
#         buckets {
#           low_value: 5.130000066757202
#           high_value: 5.720000076293945
#           sample_count: 9.98999999999909
#         }
#         buckets {
#           low_value: 5.720000076293945
#           high_value: 6.310000085830688
#           sample_count: 8.049999825160427
#         }
#         buckets {
#           low_value: 6.310000085830688
#           high_value: 6.900000095367432
#           sample_count: 4.029999984105439
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 1.0
#           high_value: 1.399999976158142
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 1.399999976158142
#           high_value: 1.5
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 1.5
#           high_value: 1.600000023841858
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 1.600000023841858
#           high_value: 3.299999952316284
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 3.299999952316284
#           high_value: 4.300000190734863
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 4.300000190734863
#           high_value: 4.599999904632568
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 4.599999904632568
#           high_value: 4.900000095367432
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 4.900000095367432
#           high_value: 5.5
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 5.5
#           high_value: 5.800000190734863
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 5.800000190734863
#           high_value: 6.900000095367432
#           sample_count: 10.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "petal-length"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 100
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 100
#       }
#       mean: 1.149
#       std_dev: 0.7878445278098973
#       min: 0.1
#       median: 1.2999999523162842
#       max: 2.5
#       histograms {
#         buckets {
#           low_value: 0.10000000149011612
#           high_value: 0.34000000134110453
#           sample_count: 29.939999991804363
#         }
#         buckets {
#           low_value: 0.34000000134110453
#           high_value: 0.5800000011920929
#           sample_count: 7.049999997764828
#         }
#         buckets {
#           low_value: 0.5800000011920929
#           high_value: 0.8200000010430812
#           sample_count: 0.965000008009373
#         }
#         buckets {
#           low_value: 0.8200000010430812
#           high_value: 1.0600000008940698
#           sample_count: 4.004999989010397
#         }
#         buckets {
#           low_value: 1.0600000008940698
#           high_value: 1.300000000745058
#           sample_count: 11.940000061839806
#         }
#         buckets {
#           low_value: 1.300000000745058
#           high_value: 1.5400000005960464
#           sample_count: 13.039999942630544
#         }
#         buckets {
#           low_value: 1.5400000005960464
#           high_value: 1.7800000004470349
#           sample_count: 4.040000037997986
#         }
#         buckets {
#           low_value: 1.7800000004470349
#           high_value: 2.0200000002980234
#           sample_count: 12.939999990314236
#         }
#         buckets {
#           low_value: 2.0200000002980234
#           high_value: 2.2600000001490117
#           sample_count: 7.039999990314236
#         }
#         buckets {
#           low_value: 2.2600000001490117
#           high_value: 2.5
#           sample_count: 9.039999990314236
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 0.10000000149011612
#           high_value: 0.20000000298023224
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 0.20000000298023224
#           high_value: 0.20000000298023224
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 0.20000000298023224
#           high_value: 0.4000000059604645
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 0.4000000059604645
#           high_value: 1.0
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.2999999523162842
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 1.2999999523162842
#           high_value: 1.5
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 1.5
#           high_value: 1.7000000476837158
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 1.7000000476837158
#           high_value: 2.0
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 2.0
#           high_value: 2.200000047683716
#           sample_count: 10.0
#         }
#         buckets {
#           low_value: 2.200000047683716
#           high_value: 2.5
#           sample_count: 10.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "petal-width"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 100
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 10.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 100
#       }
#       unique: 3
#       top_values {
#         value: "Iris-setosa"
#         frequency: 38.0
#       }
#       top_values {
#         value: "Iris-virginica"
#         frequency: 33.0
#       }
#       top_values {
#         value: "Iris-versicolor"
#         frequency: 29.0
#       }
#       avg_length: 13.149999618530273
#       rank_histogram {
#         buckets {
#           label: "Iris-setosa"
#           sample_count: 38.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "Iris-virginica"
#           sample_count: 33.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "Iris-versicolor"
#           sample_count: 29.0
#         }
#       }
#     }
#     path {
#       step: "class"
#     }
#   }
# }

# %% [markdown]
# ### Visualizando as estatísticas

# %%
tfdv.visualize_statistics(estatisticas_treinamento)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ## Inferindo e visualizando o esquema
# O schema gera um modelo para os nossos dados, podendo ser uma tarefa um pouco trabalhosa quando em conjuntos muito grandes, portanto o TF nos ajuda com isso, criando um schema inicial, que vai nos fornecer:
#
# - Tipo do dado.
# - Quais features precisam estar presentes
# - Domínio
# - Obrigatoriedade
# - Documentação dos dados
#
# Com isso, conseguimos informar aquilo que se espera dos dados, capturando problemas nos mesmos nas demais etapas.
#
# **nota:** Se trata de um schema inicial, provavelmente será necessário melhorá - lo manualmente

# %%
schema = tfdv.infer_schema(statistics=estatisticas_treinamento)
schema
# Out:
# feature {
#   name: "sepal-length"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "sepal-width"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "petal-length"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "petal-width"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "class"
#   type: BYTES
#   domain: "class"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# string_domain {
#   name: "class"
#   value: "Iris-setosa"
#   value: "Iris-versicolor"
#   value: "Iris-virginica"
# }

# %%
tfdv.display_schema(schema)
# Out:
#                   Type  Presence Valency   Domain
# Feature name
# 'sepal-length'  FLOAT   required          -
# 'sepal-width'   FLOAT   required          -
# 'petal-length'  FLOAT   required          -
# 'petal-width'   FLOAT   required          -
# 'class'         STRING  required          'class'
#                                                      Values
# Domain
# 'class'  'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'

# %% [markdown]
# ## Estatísticas para a base de teste
# Agora é a vez de calcular e ver as estatísticas da base de teste.

# %%
estatisticas_teste = tfdv.generate_statistics_from_dataframe(dataframe = dataframe_teste)

tfdv.visualize_statistics(lhs_statistics=estatisticas_teste, rhs_statistics=estatisticas_treinamento,
                          lhs_name='DATASET TESTE', rhs_name='DATASET TREINAMENTO')
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ## Checagem de anomalias nos dados de treinamento

# %%
anomalias = tfdv.validate_statistics(statistics = estatisticas_teste, schema = schema)

# %%
tfdv.display_anomalies(anomalias)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>

# %%
#tfdv.get_domain(schema, 'class').value.append('iris-virginica') podemos tambem diminuir a rigorosidade da validação do modelo sobre o domínio  
# https://github.com/tensorflow/metadata/blob/master/tensorflow_metadata/proto/v0/anomalies.proto # lista de anomalias

# %% [markdown]
# ## Criando novas anomalias
# Vamos explorar o que mais nosso detector consegue encontrar!

# %%
import numpy as np 
dataframe_teste.at[8, 'sepal-length']=np.nan
dataframe_teste.at[30, 'class']='10'

# %%
dataframe_teste
# Out:
#      sepal-length  sepal-width  petal-length  petal-width            class
# 8   NaN            2.9          1.4           0.2          Iris-setosa
# 30   4.8           3.1          1.6           0.2          10
# 145  6.7           3.0          5.2           2.3          Iris-virginica
# 107  7.3           2.9          6.3           1.8          Iris-virginica
# 49   5.0           3.3          1.4           0.2          Iris-setosa
# 83   6.0           2.7          5.1           1.6          Iris-versicolor
# 55   5.7           2.8          4.5           1.3          Iris-versicolor
# 10   5.4           3.7          1.5           0.2          Iris-setosa
# 13   4.3           3.0          1.1           0.1          Iris-setosa
# 126  6.2           2.8          4.8           1.8          Iris-virginica
# 116  6.5           3.0          5.5           1.8          Iris-virginica
# 44   5.1           3.8          1.9           0.4          Iris-setosa
# 62   6.0           2.2          4.0           1.0          Iris-versicolor
# 34   4.9           3.1          1.5           0.1          Iris-setosa
# 21   5.1           3.7          1.5           0.4          Iris-setosa
# 115  6.4           3.2          5.3           2.3          Iris-virginica
# 4    5.0           3.6          1.4           0.2          Iris-setosa
# 37   4.9           3.1          1.5           0.1          Iris-setosa
# 149  5.9           3.0          5.1           1.8          Iris-virginica
# 111  6.4           2.7          5.3           1.9          Iris-virginica
# 66   5.6           3.0          4.5           1.5          Iris-versicolor
# 42   4.4           3.2          1.3           0.2          Iris-setosa
# 121  5.6           2.8          4.9           2.0          Iris-virginica
# 25   5.0           3.0          1.6           0.2          Iris-setosa
# 35   5.0           3.2          1.2           0.2          Iris-setosa
# 50   7.0           3.2          4.7           1.4          Iris-versicolor
# 124  6.7           3.3          5.7           2.1          Iris-virginica
# 122  7.7           2.8          6.7           2.0          Iris-virginica
# 94   5.6           2.7          4.2           1.3          Iris-versicolor
# 96   5.7           2.9          4.2           1.3          Iris-versicolor
# 75   6.6           3.0          4.4           1.4          Iris-versicolor
# 141  6.9           3.1          5.1           2.3          Iris-virginica
# 99   5.7           2.8          4.1           1.3          Iris-versicolor
# 118  7.7           2.6          6.9           2.3          Iris-virginica
# 27   5.2           3.5          1.5           0.2          Iris-setosa
# 138  6.0           3.0          4.8           1.8          Iris-virginica
# 130  7.4           2.8          6.1           1.9          Iris-virginica
# 23   5.1           3.3          1.7           0.5          Iris-setosa
# 97   6.2           2.9          4.3           1.3          Iris-versicolor
# 98   5.1           2.5          3.0           1.1          Iris-versicolor
# 65   6.7           3.1          4.4           1.4          Iris-versicolor
# 11   4.8           3.4          1.6           0.2          Iris-setosa
# 9    4.9           3.1          1.5           0.1          Iris-setosa
# 88   5.6           3.0          4.1           1.3          Iris-versicolor
# 47   4.6           3.2          1.4           0.2          Iris-setosa
# 15   5.7           4.4          1.5           0.4          Iris-setosa
# 60   5.0           2.0          3.5           1.0          Iris-versicolor
# 19   5.1           3.8          1.5           0.3          Iris-setosa
# 2    4.7           3.2          1.3           0.2          Iris-setosa
# 119  6.0           2.2          5.0           1.5          Iris-virginica

# %%
estatisticas_teste = tfdv.generate_statistics_from_dataframe(dataframe = dataframe_teste)
anomalias = tfdv.validate_statistics(statistics = estatisticas_teste, schema = schema)
tfdv.display_anomalies(anomalias)
# Out:
#                Anomaly short description                                     Anomaly long description
# Feature name
# 'sepal-length'  Column dropped            The feature was present in fewer examples than expected.
# 'class'         Unexpected string values  Examples contain values missing from the schema: 10 (~2%).

# %% [markdown]
# # Gerar diferentes schemas baseados em um ambiente
# Podemos ter algumas diferenças entre o ambiente de treinamento e produção por exemplo que podem ser importantes de se levar em conta no schema.
#
# Por isso, podemos criar diferentes ambientes.

# %%
schema.default_environment.append('TRAINING')
schema.default_environment.append('SERVING')

# Removendo uma feature de um ambiente específico.
tfdv.get_feature(schema, 'class').not_in_environment.append('SERVING')

serving_anomalies_with_env = tfdv.validate_statistics(serving_stats, schema, environment='SERVING')

# %% [markdown]
# # Data Skew (Viés nos dados)
# Algo interessante que o TFDV também proporciona é a verificação por viés nos dados de treinamento em relação aos dados de produção.
#
# Acontece quando os dados de treinamento não são iguais os de produção, seja pela ausência de determinada feature ou por valores muito diferentes.
#
# Pode ser causado por:
#
# - Modificação na fonte de dados de treinamento e produção
# - Lógica diferente na geração dos dados de treino e produção
# - Falha na geração da amostra dos dados de treinamento.
